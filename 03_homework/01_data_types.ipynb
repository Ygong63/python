# %% [markdown]
# # Getting Started: Python Fundamentals
# ## Practice Problems

# %% [markdown]
# ### 1. What types are involved in the following expressions? What data type will each expression evaluate to?
#
# `8 * 2.5`

# %%
8 * 2.5
# multiplication of an integer and a floating-point number. The expression will evaluate to a floating-point number.
# Out:
# 20.0

# %%
9 / 2
#division of integers. The expression will evaluate to a floating-point number.
# Out:
# 4.5

# %% [markdown]
# `9 // -2`

# %%
9 // -2
# floor division of integers. The expression will evaluate to an integer.
# Out:
# -5

# %% [markdown]
# `1.5 * 2 >= 7 - 3`

# %%
1.5 * 2 >= 7 - 3
#multiplication and subtraction of floating-point numbers. Then did comparison. The expression will evaluate to a boolean value
# Out:
# False

# %% [markdown]
# ### 2. In which order will the expressions be evaluated.
#
# `6 * 3 + 7 * 4`
#
#
# <details>
#   <summary>Answer</summary>
#
#   `*` > `*` > `+`
# </details>
#
#
# `5 - 2 * 3 ** 4`
#
# <details>
#   <summary>Answer</summary>
#
#   `**` > `*` > `-`
# </details>
#
# `(5 - 2) * 3 ** 4`
#
# <details>
#   <summary>Answer</summary>
#
#   `(-)` > `**` > `*`
# </details>
#
# `5 + 2 >= 3 * 4`
#
# <details>
#   <summary>Answer</summary>
#
#   `*` > `+` > `>=`
# </details>

# %%
6 * 3 + 7 * 4
# Out:
# 46

# %%
5 - 2 * 3 ** 4
# Out:
# -157

# %%
(5 - 2) * 3 ** 4
# Out:
# 243

# %%
5 + 2 >= 3 * 4
# Out:
# False
